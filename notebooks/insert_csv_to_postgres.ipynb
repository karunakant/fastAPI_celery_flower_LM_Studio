# %%
import pandas as pd
df = pd.read_csv("E:\\Downloads\\Periodic Table of Elements.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AtomicNumber       118 non-null    int64
#  1   Element            118 non-null    object
#  2   Symbol             118 non-null    object
#  3   AtomicMass         118 non-null    float64
#  4   NumberofNeutrons   118 non-null    int64
#  5   NumberofProtons    118 non-null    int64
#  6   NumberofElectrons  118 non-null    int64
#  7   Period             118 non-null    int64
#  8   Group              90 non-null     float64
#  9   Phase              118 non-null    object
#  10  Radioactive        37 non-null     object
#  11  Natural            90 non-null     object
#  12  Metal              92 non-null     object
#  13  Nonmetal           19 non-null     object
#  14  Metalloid          7 non-null      object
#  15  Type               115 non-null    object
# ...

# %%
df = pd.read_csv("E:\\Downloads\\Periodic Table of Elements.csv")
df.info()
object_col = df.select_dtypes("object").columns
df[object_col] =df[object_col].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AtomicNumber       118 non-null    int64
#  1   Element            118 non-null    object
#  2   Symbol             118 non-null    object
#  3   AtomicMass         118 non-null    float64
#  4   NumberofNeutrons   118 non-null    int64
#  5   NumberofProtons    118 non-null    int64
#  6   NumberofElectrons  118 non-null    int64
#  7   Period             118 non-null    int64
#  8   Group              90 non-null     float64
#  9   Phase              118 non-null    object
#  10  Radioactive        118 non-null    object
#  11  Natural            118 non-null    object
#  12  Metal              118 non-null    object
#  13  Nonmetal           118 non-null    object
#  14  Metalloid          118 non-null    object
#  15  Type               118 non-null    object
# ...

# %%
from sqlalchemy import create_engine 
from sqlalchemy.exc import SQLAlchemyError

# %%
connection_string = "postgresql://dummy:dummy@localhost:5432/dummy" 
engine = create_engine(connection_string)

# %%
df.to_sql("periodic_table", engine, if_exists='append', index=False, chunksize=1000)
# Out:
# 118

# %%
import os

# %%
files = [
    "Solvent-SMILES-Molwtgmol-Formula-ProticAprotic.csv",
    "Reagent-SMILES-Molwtgmol-Formula-FunctionClass.csv",
    "Catalystcommonname-Typeinorgorganometallicorganic-SMILESpseudoSMILES-Molwtgmol-CASNo-SymmetricAsymmetric-HomogeneousHeterogeneous.csv",
    "Catalystcommonname-Structuralclasskeyfeature-SMILESrepresentative-Molwtgmol-CASNo-Notestypicaluse.csv"]

for f in files:
    file_path = os.path.join("D:\\AnuVeda.AI\\",f)
    if not os.path.exists(file_path):
        print(f"{file_path} does not exist")
        next

    df = pd.read_csv(file_path)
    #print(df.info())
    object_col = df.select_dtypes("object").columns
    df[object_col] =df[object_col].astype(str)
    #print(df.info())
    table_name = os.path.basename(os.path.splitext(os.path.basename(file_path))[0])
    print(table_name)
    table_name = table_name[:20]
    print(table_name)
    #object_col = df.select_dtypes("object").columns
    #df[object_col] =df[object_col].astype(str)
    df.to_sql(table_name, engine, if_exists='append', index=False, chunksize=1000)
# Out:
# Solvent-SMILES-Molwtgmol-Formula-ProticAprotic
# Solvent-SMILES-Molwt
# Reagent-SMILES-Molwtgmol-Formula-FunctionClass
# Reagent-SMILES-Molwt
# Catalystcommonname-Typeinorgorganometallicorganic-SMILESpseudoSMILES-Molwtgmol-CASNo-SymmetricAsymmetric-HomogeneousHeterogeneous
# Catalystcommonname-T
# Catalystcommonname-Structuralclasskeyfeature-SMILESrepresentative-Molwtgmol-CASNo-Notestypicaluse
# Catalystcommonname-S
